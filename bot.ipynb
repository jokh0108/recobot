# %%
#!/usr/bin/env python
# coding: utf-8

# In[ ]:


#%%
from pprint import pprint
import time
import json
import requests

from slackclient import SlackClient

class Bot():
    def __init__(self):
#     # made by hawl
#     # 'SLACK_TOKEN': 'xoxb-9983699043-717460665509-LvJsTUCLSHeHeZGIAnC5K79E',

#     # made by bell
#     'SLACK_TOKEN': 'xoxb-9983699043-712966621747-MkDbFg6u9bTCYWSdrKKMIE68',

#     # made in mymymytest bot user token
#     'SLACK_TOKEN': 'xoxb-710178628226-723981424945-IqJ5SA2ZegGWOKCU3dICsUXg',

#     # made in mymymytest user token
#     'SLACK_TOKEN': 'xoxp-710178628226-721619074613-732547954694-94ea27d50220c0e3bd0c4220d42e2b13',

        self.bot_token="xoxb-9983699043-712966621747-MkDbFg6u9bTCYWSdrKKMIE68"
        self.bot_id="BM9TLPGHJ"
        
        self.sc = SlackClient(self.bot_token)
        self.sc.rtm_connect()
    

    def run(self):
        while True:
            rtm_output = self.sc.rtm_read()
            if rtm_output:
                pprint(rtm_output)
            
            if len(rtm_output) > 0:
                rtm_output = rtm_output[0]
            else:
                time.sleep(0.2)
                continue
            
#             r= requests.get(https://slack.com/api/reactions.list)
            
            message = rtm_output.get('text', None)
            if message:
                message = message.split()
                if len(message) > 1:
                    message, query = message
                    print query
                else:
                    message = message[0]
            if message:
                print message
            if rtm_output.get('bot_id') != self.bot_id and message == u'aaa':
                res = self.sc.api_call(
                    "chat.postMessage",
                    channel=rtm_output.get('channel', None),
                    text="왈!"
                    # as_user=True
                )
                pprint(res)
                
                res = self.sc.api_call(
                    "reactions.list",
                    # channel = 'GMCH2769M' : 찾아 채널
                    channel = rtm_output.get('channel', None)
                )
                with open("./res.json", "a") as f:
                    json.dump(res, f)
                pprint(res)

#             res = self.sc.api_call(
#                 "channels.list"
#             )
#     #         pprint(res['channels'])
#             lst = res['channels']
#             for ch in lst:
#                 print ch['name'] + " : " + ch['id']
            time.sleep(0.2)

if __name__ == "__main__":
    bot = Bot()
    bot.run()

# bot = RtmBot({
#     'DEBUG': True,
#     # made by hawl
#     # 'SLACK_TOKEN': 'xoxb-9983699043-717460665509-LvJsTUCLSHeHeZGIAnC5K79E',

#     # made by bell
#     'SLACK_TOKEN': 'xoxb-9983699043-712966621747-MkDbFg6u9bTCYWSdrKKMIE68',

#     # made in mymymytest bot user token
#     'SLACK_TOKEN': 'xoxb-710178628226-723981424945-IqJ5SA2ZegGWOKCU3dICsUXg',

#     # made in mymymytest user token
#     'SLACK_TOKEN': 'xoxp-710178628226-721619074613-732547954694-94ea27d50220c0e3bd0c4220d42e2b13',

#     'ACTIVE_PLUGINS': [
#         'plugins.reco.RecoPlugin'
#     ]
# })
# bot.start()


#%%
# Out:
# [{u'type': u'hello'}]
# [{u'channel': u'GMCH2769M', u'type': u'user_typing', u'user': u'UKVNRSKDM'}]
# [{u'channel': u'GMCH2769M', u'type': u'user_typing', u'user': u'UKVNRSKDM'}]
# [{u'channel': u'GMCH2769M',
#   u'client_msg_id': u'40d5f450-2e71-40fc-b28f-805d22a0bea3',
#   u'event_ts': u'1566292437.000300',
#   u'source_team': u'T09UXLK19',
#   u'suppress_notification': False,
#   u'team': u'T09UXLK19',
#   u'text': u'aaa',
#   u'ts': u'1566292437.000300',
#   u'type': u'message',
#   u'user': u'UKVNRSKDM',
#   u'user_team': u'T09UXLK19'}]
# aaa
# {u'channel': u'GMCH2769M',
#  u'headers': {u'Access-Control-Allow-Headers': u'slack-route, x-slack-version-ts',
#               u'Access-Control-Allow-Origin': u'*',
#               u'Access-Control-Expose-Headers': u'x-slack-req-id, retry-after',
#               u'Cache-Control': u'private, no-cache, no-store, must-revalidate',
#               u'Connection': u'keep-alive',
#               u'Content-Encoding': u'gzip',
# ...
